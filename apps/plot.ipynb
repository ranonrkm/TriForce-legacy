# %%
import os
import sys
root_dir = os.path.abspath('/home/hanshis/workspace/LongContextInfer')
sys.path.append(root_dir)

from utils.plot import plot_test

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_retrieval.csv'
xaxis = 'chunk_size'
title = 'KV Retrieval (32K prefill)'
plot_test(file_path, xaxis, title)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Plotting dataset=password, budget=0.05
# ['1', '2', '4', '8', '16', '32', '64', '128', '256', '512'] [0.9999224806201551, 0.9998449612403101, 0.9994591532498509, 0.9996899224806203, 0.9994573643410852, 0.998294573643411, 0.9975992844364936, 0.9958950506857484, 0.9583778447856679, 0.9759895331931594]
# Plotting dataset=password, budget=0.03
# ['1', '2', '4', '8', '16', '32', '64', '128', '256', '512'] [0.9996899224806203, 0.9999224806201551, 0.9997674418604652, 0.9998449612403101, 0.9993023255813952, 0.9991472868217053, 0.9976744186046511, 0.9921067382230171, 0.7056861361650547, 0.02139125769818921]
# Plotting dataset=password, budget=0.08
# ...

# %%
import os
import sys
root_dir = os.path.abspath('/home/hanshis/workspace/LongContextInfer')
sys.path.append(root_dir)

from utils.plot import plot_test

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_streamllm.csv'
xaxis = 'budget'
title = 'StreamLLM (32K prefill)'
plot_test(file_path, xaxis, title)
# Out:
# Plotting dataset=password
# Plotting dataset=pg19

# %%
import os
import sys
root_dir = os.path.abspath('/home/hanshis/workspace/LongContextInfer')
sys.path.append(root_dir)

from utils.plot import plot_test

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_h2o.csv'
xaxis = 'budget'
title = 'H2O (32K prefill)'
plot_test(file_path, xaxis, title)
# Out:
# Plotting dataset=password
# Plotting dataset=pg19

# %%
import os
import sys
root_dir = os.path.abspath('/home/hanshis/workspace/LongContextInfer')
sys.path.append(root_dir)

from utils.plot import plot_test

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_topk.csv'
xaxis = 'budget'
title = 'TopK (32K prefill)'
plot_test(file_path, xaxis, title)
# Out:
# Plotting dataset=password
# Plotting dataset=pg19

# %%
import os
import sys
root_dir = os.path.abspath('/home/hanshis/workspace/LongContextInfer')
sys.path.append(root_dir)

from utils.plot import plot_test

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_evict_h2o.csv'
xaxis = 'dataset'
title = 'Evict H2O with 68m-256 (32K prefill)'
plot_test(file_path, xaxis, title)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Plotting

# %%
import os
import sys
root_dir = os.path.abspath('/home/hanshis/workspace/LongContextInfer')
sys.path.append(root_dir)

from utils.plot import plot_test

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_evict_streamllm.csv'
xaxis = 'dataset'
title = 'Evict StreamLLM (32K prefill)'
plot_test(file_path, xaxis, title)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Plotting

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/home/hanshis/workspace/LongContextInfer/benchmark/report/L40_llama_7B_128K_graph.csv'
df = pd.read_csv(file_path)
table = df[df['model'] == 'JackFram/llama-68m']
x_list = table['prefill'].unique()
x_list.sort()
y_list = []
for x in x_list:
    y_list.append(table[table['prefill'] == x]['latency'].mean())
plt.plot(x_list, y_list, label='llama-68m')

# table = df[df['model'] == 'NousResearch/Yarn-Llama-2-7b-128k']
# x_list = table['prefill'].unique()
# x_list.sort()
# y_list = []
# for x in x_list:
#     y_list.append(table[table['prefill'] == x]['latency'].mean())
# plt.plot(x_list, y_list, label='llama-7B')
plt.grid()
plt.legend()
plt.xlabel('Prefill')
plt.ylabel('Latency (s)')
plt.title('Llama-68m (L40 with CUDA Graph)')
# Out:
# Text(0.5, 1.0, 'Llama-68m (L40 with CUDA Graph)')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pytest import mark

file_path = '/home/hanshis/workspace/LongContextInfer/benchmark/report/L40_llama_7B_128K_graph.csv'
df = pd.read_csv(file_path)
table = df[df['model'] == 'NousResearch/Yarn-Llama-2-7b-128k']
x_list = table['prefill'].unique()
x_list.sort()
y_list = []
for x in x_list:
    y_list.append(table[table['prefill'] == x]['latency'].mean())
plt.plot(x_list, y_list, label='llama-7B (flash-attn)', marker='o')

file_path = '/home/hanshis/workspace/LongContextInfer/benchmark/report/L40_torch_vanilla.csv'
df = pd.read_csv(file_path)
table = df
x_list = table['prefill'].unique()
x_list.sort()
y_list = []
for x in x_list:
    y_list.append(table[table['prefill'] == x]['latency'].mean())
plt.plot(x_list, y_list, label='llama-7B-torch (vanilla)', marker='o')

file_path = '/home/hanshis/workspace/LongContextInfer/benchmark/report/L40_torch_new.csv'
df = pd.read_csv(file_path)
table = df
x_list = table['prefill'].unique()
x_list.sort()
y_list = []
for x in x_list:
    y_list.append(table[table['prefill'] == x]['latency'].mean())
plt.plot(x_list, y_list, label='llama-7B-torch (scaled_dot_product_attention)', marker='o')

plt.xlabel('Prefill')
plt.ylabel('Latency (s)')
plt.grid()
plt.legend()
plt.title('Llama-7B (L40 with CUDA Graph)')
# Out:
# Text(0.5, 1.0, 'Llama-7B (L40 with CUDA Graph)')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pytest import mark

file_path = '/home/hanshis/workspace/LongContextInfer/benchmark/report/L40_torch_vanilla.csv'
df = pd.read_csv(file_path)
table = df
x_list = table['prefill'].unique()
x_list.sort()
y_list = []
for x in x_list:
    y_list.append(table[table['prefill'] == x]['latency'].mean())
plt.plot(x_list, y_list, label='llama-7B', marker='o')
plt.xlabel('Prefill')
plt.ylabel('Latency (s)')
plt.grid()
plt.legend()
plt.title('Llama-7B (L40 with CUDA Graph)')
# Out:
# Text(0.5, 1.0, 'Llama-7B (L40 with CUDA Graph)')

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_evict_streamllm.csv'
df = pd.read_csv(file_path)
prefill = df['prefill'].unique()
prefill.sort()
y_list = []
for p in prefill:
    table = df[df['prefill'] == p]
    y_list.append(table['acceptance_rate'].mean())
# set fig size
plt.figure(figsize=(25, 5))
plt.plot([str(x) for x in prefill], y_list, marker='o')
plt.grid()
plt.xlabel('Prefill')
plt.ylabel('acceptance_rate')
plt.title('Evict StreamLLM 68m for 7B-128K (pg19 dataset)')
# Out:
# Text(0.5, 1.0, 'Evict StreamLLM 68m for 7B-128K (pg19 dataset)')

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_evict_streamllm.csv'
df = pd.read_csv(file_path)

prefill = [1, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 49152, 65536, 98304, 114688, 129668]

y_list = []
for p in prefill:
    table = df[df['prefill'] == p]
    if p == 512 or p == 1024:
        y_list.append(table['acceptance_rate'][130:].mean())
    else:
        y_list.append(table['acceptance_rate'].mean())
# set fig size
plt.figure(figsize=(12, 5))
plt.plot([str(x) for x in prefill], y_list, marker='o', label='68m for 7B')
plt.grid()
plt.xlabel('Prefill')
plt.ylabel('acceptance_rate')
plt.title('pg19 dataset')

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_graph_chain.csv'
df = pd.read_csv(file_path)

prefill = [1, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 49152]

y_list = []
for p in prefill:
    table = df[df['prefill'] == p]
    y_list.append(table['acc_rate_middle'].mean())

prefill=[65536, 98304, 114688, 129668, 130772]
file_path = '/home/hanshis/workspace/LongContextInfer/test/report/A100_graph_chain.csv'
df = pd.read_csv(file_path)
for p in prefill:
    table = df[df['prefill'] == p]
    y_list.append(table['acc_rate_middle'].mean())
prefill = [1, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 49152, 65536, 98304, 114688, 129668, 130000]
plt.plot([str(x) for x in prefill], y_list, marker='o', label='68m for 7B-StreamLLM ')



file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_graph_chain_retrieval.csv'
df = pd.read_csv(file_path)

prefill = [1, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 49152]

y_list = []
for p in prefill:
    table = df[df['prefill'] == p]
    y_list.append(table['acc_rate_middle'].mean())

prefill=[65536, 98304, 114688, 129668, 130772]
file_path = '/home/hanshis/workspace/LongContextInfer/test/report/A100_graph_chain_retrieval.csv'
df = pd.read_csv(file_path)
for p in prefill:
    table = df[df['prefill'] == p]
    y_list.append(table['acc_rate_middle'].mean())
prefill = [1, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 49152, 65536, 98304, 114688, 129668, 130000]
# set fig size
plt.plot([str(x) for x in prefill], y_list, marker='o', label='68m for 7B-Retrieval ')


plt.legend()

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_graph_chain.csv'
df = pd.read_csv(file_path)

prefill = [1, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 49152]

y_list = []
for p in prefill:
    table = df[df['prefill'] == p]
    y_list.append(table['acc_rate_middle'].mean())

prefill=[65536, 98304, 114688, 129668, 130772]
file_path = '/home/hanshis/workspace/LongContextInfer/test/report/A100_graph_chain.csv'
df = pd.read_csv(file_path)
for p in prefill:
    table = df[df['prefill'] == p]
    y_list.append(table['acc_rate_middle'].mean())
prefill = [1, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 49152, 65536, 98304, 114688, 129668, 130772]
# set fig size
plt.figure(figsize=(12, 5))
plt.plot([str(x) for x in prefill], y_list, marker='o')
plt.grid()
plt.xlabel('Prefill')
plt.ylabel('acceptance_rate')
plt.title('Evict StreamLLM 68m for 7B-StreamLLM-128K (pg19 dataset)')
# Out:
# Text(0.5, 1.0, 'Evict StreamLLM 68m for 7B-StreamLLM-128K (pg19 dataset)')

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_graph_chain_retrieval.csv'
df = pd.read_csv(file_path)

prefill = [1, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 49152]

y_list = []
for p in prefill:
    table = df[df['prefill'] == p]
    y_list.append(table['acc_rate_middle'].mean())

prefill=[65536, 98304, 114688, 129668, 130772]
file_path = '/home/hanshis/workspace/LongContextInfer/test/report/A100_graph_chain_retrieval.csv'
df = pd.read_csv(file_path)
for p in prefill:
    table = df[df['prefill'] == p]
    y_list.append(table['acc_rate_middle'].mean())
prefill = [1, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 49152, 65536, 98304, 114688, 129668, 130772]
# set fig size
plt.figure(figsize=(12, 5))
plt.plot([str(x) for x in prefill], y_list, marker='o')
plt.grid()
plt.xlabel('Prefill')
plt.ylabel('acceptance_rate')
plt.title('Evict StreamLLM 68m for 7B-Retrieval-128K (pg19 dataset)')
# Out:
# Text(0.5, 1.0, 'Evict StreamLLM 68m for 7B-Retrieval-128K (pg19 dataset)')

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_streamllm.csv'
df = pd.read_csv(file_path)
df = df[df['target'] == 'NousResearch/Yarn-Llama-2-7b-128k']
df = df[df['dataset'] == 'pg19']
df = df[df['budget'] == 0.1]

x_list = df['prefill'].unique()
x_list.sort()
y_list = []
for x in x_list:
    y_list.append(df[df['prefill'] == x]['acceptance_rate'].mean())
plt.plot([str(x) for x in x_list], y_list, label='streamllm', marker='o')
plt.grid()
plt.xlabel('Prefill')
plt.ylabel('acceptance_rate')
plt.title('7B-StreamLLM-128K (pg19 dataset)')
# Out:
# Text(0.5, 1.0, '7B-StreamLLM-128K (pg19 dataset)')

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/home/hanshis/workspace/LongContextInfer/test/report/L40_retrieval.csv'
df = pd.read_csv(file_path)
df = df[df['target'] == 'NousResearch/Yarn-Llama-2-7b-128k']
df = df[df['dataset'] == 'pg19']
df = df[df['budget'] == 0.1]

x_list = df['prefill'].unique()
x_list.sort()
y_list = []
for x in x_list:
    y_list.append(df[df['prefill'] == x]['acceptance_rate'].mean())
plt.plot([str(x) for x in x_list], y_list, label='streamllm', marker='o')
plt.grid()
plt.xlabel('Prefill')
plt.ylabel('acceptance_rate')
plt.title('7B-StreamLLM-128K (pg19 dataset)')
# Out:
# Text(0.5, 1.0, '7B-StreamLLM-128K (pg19 dataset)')
