# %%
import os
import sys
sys.path.append('/home/hanshis/workspace/LongContextInfer/')

from data.dataset import get_dataset
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('JackFram/llama-68m')
tokenized_prompts, ans = get_dataset(dataset_name='needle_retrieval', tokenizer=tokenizer, datalen=100*1024)
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 100%|██████████| 100/100 [16:28<00:00,  9.89s/it]

# %% [markdown]
# import torch
#
# torch.load('attn_weights_10.pt')

# %%
import torch

a = torch.load('../attn_weights_10.pt')

# %%
a[0].shape
# Out:
# torch.Size([32, 1, 1025])

# %%
import math
math.sqrt(1024)
# Out:
# 32.0

# %%
181*181
# Out:
# 32761

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(20, 10))
plt.imshow(a[0,3][0,0:1024].reshape(32,32).cpu().numpy())

# %%
import pickle
with open('../data/needle_retrieval.pkl', 'wb') as f:
    pickle.dump((tokenized_prompts, ans), f)

# %%
tokenized_prompts[0].shape
# Out:
# torch.Size([1, 102400])

# %%
ans[0]
# Out:
# 'hCyeEvGw-o3WTZ3vwzmni-iDq-yyKJes'

# %%
tk[1]
# Out:
# tensor([[   1,  887,  526,  ..., 1209, 1820,  338]])

# %%
tokenizer.decode(tk[1][0])
# Out:
# "<s> You are a helpful assistant. USER: There is an important info hidden inside a lot of irrelevant text. Find it and memorize them. I will quiz you about the important information there.\nThe grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again
# ...

# %%
tk
# Out:
# [tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
#  tensor([[   1,  887,  526,  ..., 1209, 1820,  338]]),
# ...

# %%
ans_
# Out:
# ['Jv6TG36-rkMrfYEJUfUq72Lr1oAeuGj6t8FizWyC89BsUrtEidjO35i7T4jy2l7XmDzbgD3py2CuEVW4kmnqfiHBh9sw_FS3_jwfRcZ84qn1CR9AuJl5JM2tUtTREZTv5tw8lBxlyIyIJHec6JVjWAmG6nHjsDHmC7i8XE3ax9Z4IeSGWYr7W1W_j1kqUQCZ9iZ4MuwQqTCO04knOi3m5WGJYQ4LqlcxoSFYUan6tVWviv2H2jG59ZAnkQetvq8U',
#  'FLyQCPRq0hSAUMhQPLS8XVCcShLrnl5L2Fzccgkjm0xpxBaAsUNOlHCYLhBR-2YekTBeiW_GY7d7sqf_E4jH5M8X8EYKeL4vgKdIyO5SV6XR8G18vMq8xNB7MHoQqpNCfCWB5RAGcIpSB7s-BpJIKzW9xZoM4ISOyDLnqXokTN593uqXkfe_DJG-TBpClYAeSqimKBl0mXrgslm0Yr8DhOOky9Kr2lBohUJTlHnav7wea9oIh5AsV9Z5AHPtLYA3',
#  'GkVMivX9VgyVaFLEpHsyo7aYh4-UQgO4QSWkTmThPDDHCgF3PBLFiDl44MMaR1hje5RQU24LZLGC0M08vD7J-FighklztkF7wUsbxRY6ZORv51GERjutvsXoYBCb72pChqWfXbJujn-xbuzFm0-FpVksPXAF216TOGYZEA47XGlXBVwwqUBMjCFF-5p6P2OWlMpWrI8DO2shZnES5sWgCq9CVY08jr97KZ9EvGJKnrYOzqb11xfK6_CeSM0DC7ed',
# ...

# %%
with open('../data/needle_retrieval.pkl', 'rb') as f:
    tk, ans_ = pickle.load(f)

# %%
budget_list = [bud *4096 for bud in range(1, 32)]
for bug in budget_list:
    print(f"CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget {bug}")
# Out:
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 4096
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 8192
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 12288
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 16384
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 20480
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 24576
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 28672
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 32768
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 36864
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 40960
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 45056
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 49152
# CUDA_VISIBLE_DEVICES=1,2 python observation/needle_test.py --budget 53248
# ...

# %%
127*1024
# Out:
# 130048

# %%
len(ans[0])
# Out:
# 32

# %%
tokenizer.decode(needles[-1][0])
# Out:
# "<s> You are a helpful assistant. USER: There is an important info hidden inside a lot of irrelevant text. Find it and memorize them. I will quiz you about the important information there.\nThe grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again. The grass is green. The sky is blue. The sun is yellow. Here we go. There and back again
# ...

# %%
'13' == '12'
# Out:
# False

# %%
len('y8tm3OZnUUcEmTABsDMa8exqUaa17ZPIeObQpeRM4Ne9o9tkK4Jk_0bxqV9sjzBMGmbZTg0H_XG8wR16RD3jrcTbLQQcaKUsmcG2hFnhBATECIHSPjQvjssxyBDh_Vi3vFYNRK17ZBix53mc3VhOSdoUouU3KKO508f9B0o-19h6x1FIS-c1CtOfxH9cdGv38ay99jz-8wQV6IfDLYIbRxa8uJAnqUvCNmz4rZX2KBTlBj8Qwf1_ihdICAbHPdS')
# Out:
# 255
